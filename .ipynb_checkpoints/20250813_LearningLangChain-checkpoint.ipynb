# %% [markdown]
# # E-Book: Learning LangChain (Oshin)
# ## Amed
# ### https://www.oreilly.com/library/view/learning-langchain/9781098167271/

# %% [markdown]
# Rag system to update LLM with current data.
# four steps to preprocess your documens for LLM usage
#
# langchain: free library to do this preprocessing
#
# load all pdfs from a directory
# 1.) create chunks from the text
# 2.) create vector embeddings
# 3.)
#
# Basic RAG:
# question->indexing->retrieval-> context
#
# RAG idea
# the text of the documents is splitted and chunked and stored vector based.
# If you prompt a question based on the context of your documents, your prompt will be extended by possibly relevant parts of the document and this extended token is processed by the ordinary llm.
