# %%
from z3 import z3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from z3 import z3
#
# ModuleNotFoundError: No module named 'z3'
