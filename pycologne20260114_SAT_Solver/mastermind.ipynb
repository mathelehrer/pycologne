# %%
import random
import itertools
import numpy as np

from mastermind import Game, score

# %% [markdown]
# # Mastermind
#
# *Mastermind* ist ein klassisches Logikspiel für zwei Personen: einen *Codemaster* und eine:n *Rater:in*.
# Ziel ist es, einen $n$ stelligen geheimen Farbcode zu erraten.
# Sie übernehmen die Rolle des *Raters* / der *Raterin* und der Computer ist der *Codemaster*.
#
# ## 🕹 Spielablauf
#
# 1. **Code erstellen**
#    Der Codemaster wählt heimlich einen $n$ stelligen Code aus.
#
# 2. **Raten**
#    Der/die Rater:in stellt einen Farbvorschlag auf die Rateleiste.
#
# 3. **Auswerten**
#    Der Codemaster gibt Feedback:
#    - ⚫ **Schwarz:** Richtige Farbe am richtigen Platz
#    - ⚪ **Weiß:** Richtige Farbe am falschen Platz
#    - Keine Pin: Farbe kommt im Code nicht vor
#
# 4. **Wiederholen**
#    Der/die Rater:in versucht es erneut, mit dem Feedback im Hinterkopf.
#
# ## 🏁 Spielende
# - Der Rater gewinnt, wenn er den Code richtig errät.
#
# Viel Spaß beim Knobeln!

# %% [markdown]
# # Umsetzung in Jupyter / Python

# %%
g = Game(15, 8)

# %% [markdown]
# Code raten:

# %%
g.guess([2, 1] + [2] * 13)
# Out:
# (2, 2)

# %% [markdown]
# Fancy Spielfeld anzeigen:

# %%
g.display()

# %%
b, w = g.guess([3, 4, 5, 6, 7]) # <- Hier Ihren Code eintragen
g.display()

# %%
g.guesses
